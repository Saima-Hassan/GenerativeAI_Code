# %% [markdown]
#  This notebook will show you how to get started with the Gemini API and walk you through some of the example prompts and techniques.

# %% [markdown]
# **Colab** is a free, cloud-based platform that allows you to write and execute Python code directly in your web browser. It offers GPU acceleration, seamless integration with** Google Drive**, and access to libraries for data analysis and machine learning."

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
#
# <div class="markdown-google-sans">
#
# ## **What is Colab?**
# </div>
#
# Google Colaboratory is a free online cloud-based Jupyter notebook environment that allows us to train our machine learning and deep learning models on CPUs, GPUs, and TPUs.
#
# - Ready-to-Use Environment
# - Access to GPUs free of charge
# - Collaboration
#
# </div>

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Prerequisit**
# </div>
#
# If you do not currently have access to Google Colab, you can Go to <a href="https://colab.research.google.com">sign up</a>  for a free account
# </div>

# %% [markdown]
# ![gg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #AI features
#  Colab now has AI features powered by Gemini. Today we're talking about Colab and three AI-powered tools, those features are Generate Code, Explain Error and Gemini Chat.

# %%
# prompt: Write a Python code for a square root function

import math

def square_root(number):
  """
  This function calculates the square root of a given number.

  Args:
    number: The number for which to calculate the square root.

  Returns:
    The square root of the number, or None if the number is negative.
  """
  if number < 0:
    return None  # Cannot calculate square root of a negative number
  else:
    return math.sqrt(number)

# %%
square_root(49)
# Out:
# 7.0

# %% [markdown]
# ## Code Generation
#
# Write a Python code for a square root function

# %%
# prompt: create a data frame that has midterm grades fpr 10 students

import pandas as pd
import numpy as np

# Create a list of student names
students = [f"Student {i+1}" for i in range(10)]

# Generate random midterm grades between 60 and 100
midterm_grades = np.random.randint(60, 101, size=10)

# Create a dictionary to store the data
data = {'Student': students, 'Midterm Grade': midterm_grades}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#       Student  Midterm Grade
# 0   Student 1             64
# 1   Student 2             94
# 2   Student 3             72
# 3   Student 4             93
# 4   Student 5             67
# 5   Student 6             92
# 6   Student 7             94
# 7   Student 8             85
# 8   Student 9             91
# 9  Student 10             85
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Midterm Grade'].plot(kind='hist', bins=20, title='Midterm Grade')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Midterm Grade'].plot(kind='line', figsize=(8, 4), title='Midterm Grade')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['Midterm Grade'].plot(kind='hist', bins=20, title='Midterm Grade')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Error Explanation

# %%
math.sqrt(49)
# Out:
# 7.0

# %% [markdown]
# ## Code Explanation

# %%
# prompt: explain "math.sqrt(49)"

The expression `math.sqrt(49)` calculates the square root of 49 using the `sqrt()` function from the `math` module in Python.  The square root of 49 is 7, because 7 * 7 = 49.  Therefore, the expression evaluates to `7`.

# %% [markdown]
# ## Image Analysis

# %%
# prompt: Describe the content of this image https://ichef.bbci.co.uk/food/ic/food_16x9_1600/recipes/rainbow_cake_20402_16x9.jpg

# The provided image URL depicts a vibrant rainbow cake.  The cake is layered, with each layer showcasing a different color of the rainbow, creating a visually appealing and colorful dessert.

# %%
# prompt: Describe the content of this image https://ichef.bbci.co.uk/food/ic/food_16x9_1600/recipes/rainbow_cake_20402_16x9.jpg

# %% [markdown]
# #Get started with the Gemini API
#
# To begin using the Gemini API, you need to acquire an API key. If you haven’t obtained one yet, you can easily create a key within **[Google AI Studio](https://ai.google.dev/gemini-api/docs/api-key).**
#
#
# In Colab, add the key to the secrets manager under the "🔑" in the left panel. Give it the name GEMINI_API_KEY.

# %% [markdown]
# ![gemini.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Set up your API key
# To run the following cell, your API key must be stored in a Colab Secret named GEMINI_API_KEY.

# %%
# !pip install -U -q "google-generativeai>=0.8.3"

# %% [markdown]
# ## Import packages
# Import the necessary packages.

# %%
import google.generativeai as genai
from IPython.display import HTML, Markdown, display
import os
import textwrap


def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %%
# Used to securely store your API key
from google.colab import userdata

GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')
genai.configure(api_key=GEMINI_API_KEY)

# %%
GOOGLE_API_KEY = "AIzaSyAWFEyHdkvKefYAK2WEV-H5NIfyDN4s8Lg"
#AIzaSyAc1KDIVBLdTq1m1CGTTNRmtLK140AxYfY"
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# ## Install the Python SDK

# %% [markdown]
# # Choose a model
# The Gemini API provides access to a number of models from the Gemini model family. Read about the available models and their capabilities on the [model overview page](https://ai.google.dev/gemini-api/docs/models/gemini).
#
# In this step you'll use the API to list all of the available models.

# %%
for model in genai.list_models():
  print(model.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/learnlm-1.5-pro-experimental
# models/gemini-exp-1114
# models/gemini-exp-1121
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %% [markdown]
# ## Search for Specific Model Supporting 'generateContent
# The code iterates through all available models from the genai.list_models() function and checks if each model supports the "generateContent" method.

# %%
for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/learnlm-1.5-pro-experimental
# models/gemini-exp-1114
# models/gemini-exp-1121

# %% [markdown]
# ## Search for Models Supporting Message Generation
# To search for models that support message generation, we can writ the following code

# %%
for m in genai.list_models():
    if "generateMessage" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/chat-bison-001

# %% [markdown]
# This will list all models and their supported methods

# %%
for m in genai.list_models():
    print(f"Model: {m.name}, Supported Methods: {m.supported_generation_methods}")
# Out:
# Model: models/chat-bison-001, Supported Methods: ['generateMessage', 'countMessageTokens']
# Model: models/text-bison-001, Supported Methods: ['generateText', 'countTextTokens', 'createTunedTextModel']
# Model: models/embedding-gecko-001, Supported Methods: ['embedText', 'countTextTokens']
# Model: models/gemini-1.0-pro-latest, Supported Methods: ['generateContent', 'countTokens']
# Model: models/gemini-1.0-pro, Supported Methods: ['generateContent', 'countTokens']
# Model: models/gemini-pro, Supported Methods: ['generateContent', 'countTokens']
# Model: models/gemini-1.0-pro-001, Supported Methods: ['generateContent', 'countTokens', 'createTunedModel']
# Model: models/gemini-1.0-pro-vision-latest, Supported Methods: ['generateContent', 'countTokens']
# Model: models/gemini-pro-vision, Supported Methods: ['generateContent', 'countTokens']
# Model: models/gemini-1.5-pro-latest, Supported Methods: ['generateContent', 'countTokens']
# ...

# %% [markdown]
# # Run your first prompt
# In this step, you will test that your API key is set up correctly by making a request. The gemini-1.5-flash model has been selected here.

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
prompt ="Explain AI in one sentences to a kid."
response = model.generate_content(prompt)
print(response.text)
# Out:
# AI is like giving a computer a brain so it can learn and do smart things!

# %% [markdown]
# ## Start a chat
# The previous example uses a single-turn, text-in/text-out structure, but you can also set up a multi-turn chat structure too.
# This code snippet is an example of how to interact with a conversational AI model using a chat-based approach.

# %%
chat = model.start_chat(history=[])
response = chat.send_message('Hello! My name is Saima.')
print(response.text)
# Out:
# Hello Saima! It's nice to meet you.  How can I help you today?

# %%
response = chat.send_message('Can you tell something interesting facts about Pakistan?')
print(response.text)
# Out:
# Pakistan boasts a fascinating history and diverse geography, leading to some truly interesting facts:
#
# * **The Indus Valley Civilization:** Pakistan is home to the ruins of the Indus Valley Civilization, one of the world's oldest civilizations, predating both ancient Egypt and Mesopotamia.  Mohenjo-daro and Harappa are two of the most significant sites.
#
# * **The World's Highest Polo Ground:**  The Shandur Polo Ground, situated in the Himalayas, is considered the highest polo ground in the world.  The matches are a spectacular sight.
#
# * **The Karakoram Highway:**  This is one of the highest paved roads in the world, traversing the Karakoram mountain range and connecting Pakistan and China.  It's a breathtaking but challenging drive.
#
# * **Deosai Plains:** Known as the "Land of Giants," Deosai is one of the highest plateaus in the world, offering stunning landscapes and unique wildlife.
#
# ...

# %%
# While you have the `chat` object around, the conversation state
# persists. Confirm that by asking if it knows my name.
response = chat.send_message('Do you remember what my name is?')
print(response.text)
# Out:
# Yes, your name is Saima.

# %%
print(chat.history)
# Out:
# [parts {
#   text: "Hello! My name is Saima."
# }
# role: "user"
# , parts {
#   text: "Hello Saima! It\'s nice to meet you.  How can I help you today?\n"
# }
# role: "model"
# , parts {
#   text: "Can you tell something interesting facts about Pakistan?"
# }
# role: "user"
# , parts {
# ...

# %% [markdown]
# # Explore generation parameters
# Every prompt you send to the model includes parameters that control how the model generates responses. Use a genai.GenerationConfig to set these, or omit it to use the defaults.
# ## Output length
# When generating text with an LLM, the output length affects cost and performance. Generating more tokens increases computation, leading to higher energy consumption, latency, and cost.
#
#  To stop the model from generating tokens pass a limit, you can specify the max_output_length parameter when using the Gemini API. Specifying this parameter does not influence the generation of the output tokens, so the output will not become more stylistically or textually succinct, but it will stop generating tokens once the specified length is reached. Prompt engineering may be required to generate a more complete output for your given limit.

# %%
short_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(max_output_tokens=200))

response = short_model.generate_content('Write a 1000 word essay on the important festivals of Pakistan.')
print(response.text)
# Out:
# ## A Tapestry of Celebrations: Exploring the Important Festivals of Pakistan
#
# Pakistan, a land of vibrant cultures and diverse ethnicities, boasts a rich tapestry of festivals that reflect its unique history, religious beliefs, and societal values. These celebrations, ranging from grand national events to intimate local gatherings, are integral to Pakistani life, providing opportunities for communal bonding, religious devotion, and joyous expression. While the country's Muslim majority significantly shapes its festival calendar, the diverse religious and ethnic groups contribute their own vibrant celebrations, creating a kaleidoscope of cultural expressions. This essay explores some of the most important festivals of Pakistan, highlighting their significance and the role they play in shaping national identity.
#
# ...

# %%
response = short_model.generate_content('Write a short poem on the importance of gem and minals in Pakistan.')
print(response.text)

# %%
short_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(max_output_tokens=150))
response = short_model.generate_content('Write a concise 50-word note on the use of Generative AI in healthcare, focusing on its applications in diagnostics, personalized treatment, and drug discovery')
print(response.text)

# %% [markdown]
# ## Temperature
# Temperature is a parameter in language models that controls the randomness of the generated text. By adjusting the temperature, you can influence the creativity and diversity of the output.
# The optimal temperature setting will vary depending on the specific task and desired outcome. A higher temperature (e.g., 1.0) makes the output more diverse and creative, while a lower temperature (e.g., 0.2) results in more deterministic and focused responses.

# %%
import time

high_temp_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(temperature=0.9))

for _ in range(4):
  response = high_temp_model.generate_content('Pick a random colour... (answer in a single word)')
  if response.parts:
    print(response.text, '-' * 25)

  # Slow down a bit so we don't get Resource Exhausted errors.
  time.sleep(20)
# Out:
# Purple
#  -------------------------
# Purple
#  -------------------------
# Crimson
#  -------------------------
# Aquamarine
#  -------------------------

# %% [markdown]
# Now try the same prompt with temperature set to zero. Note that the output is not completely deterministic, as other parameters affect token selection, but the results will tend to be more stable

# %%
import time

high_temp_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(temperature=0.0))

for _ in range(4):
  response = high_temp_model.generate_content('Pick a random colour... (answer in a single word)')
  if response.parts:
    print(response.text, '-' * 25)

  # Slow down a bit so we don't get Resource Exhausted errors.
  time.sleep(20)
# Out:
# Purple
#  -------------------------
# Purple
#  -------------------------
# Purple
#  -------------------------
# Purple
#  -------------------------

# %% [markdown]
# ## Zero-shot
# Zero-shot prompts are prompts that describe the request for the model directly.

# %%
prompt = """
Classify the following text into one of the labels: 'dog' or 'cat'.

Text: "I saw a furry animal in the park today with a short tail and big eyes."
Label:
"""

response = model.generate_content(
    contents=prompt, generation_config=genai.GenerationConfig() # Create an instance of GenerationConfig
).text
print(response)
# Out:
# Label: cat

# %% [markdown]
# ## One-shot and few-shot¶
# Providing an example of the expected response is known as a "one-shot" prompt. When you provide multiple examples, it is a "few-shot" prompt.

# %%
prompt = """
What is the topic for a given news headline? \n
- business \n
- entertainment \n
- health \n
- sports \n
- technology \n\n

Text: Pixel 7 Pro Expert Hands On Review. \n
The answer is: technology \n

Text: Quit smoking? \n
The answer is: health \n

Text: Birdies or bogeys? Top 5 tips to hit under par \n
The answer is: sports \n

Text: Relief from local minimum-wage hike looking more remote \n
The answer is: business \n

Text: You won't guess who just arrived in Bari, Italy for the movie premiere. \n
The answer is:
"""

response = model.generate_content(
    contents=prompt, generation_config=genai.GenerationConfig() # Create an instance of GenerationConfig
).text
print(response)
# Out:
# entertainment

# %% [markdown]
# ## Chain of Thought (CoT)¶
# Direct prompting on LLMs can return answers quickly and (in terms of output token usage) efficiently, but they can be prone to hallucination. The answer may "look" correct (in terms of language and syntax) but is incorrect in terms of factuality and reasoning.
#
# Chain-of-Thought prompting is a technique where you instruct the model to output intermediate reasoning steps, and it typically gets better results, especially when combined with few-shot examples. It is worth noting that this technique doesn't completely eliminate hallucinations, and that it tends to cost more to run, due to the increased token count.
#
# As models like the Gemini family are trained to be "chatty" and provide reasoning steps, you can ask the model to be more direct in the prompt.

# %%
prompt = """When I was 4 years old, my partner was 3 times my age. Now, I
am 20 years old. How old is my partner? Return the answer immediately."""

model = genai.GenerativeModel('gemini-1.5-flash-latest')
response = model.generate_content(prompt)

print(response.text)
# Out:
# 47

# %% [markdown]
# Now try the same approach, but indicate to the model that it should "think step by step".

# %%
prompt = """When I was 4 years old, my partner was 3 times my age. Now,
I am 20 years old. How old is my partner? Let's think step by step."""

response = model.generate_content(prompt)
print(response.text)
# Out:
# Step 1: Find the partner's age when you were 4.
#
# * You were 4, and your partner was 3 times your age, so your partner was 4 * 3 = 12 years old.
#
# Step 2: Find the age difference between you and your partner.
#
# * The age difference is 12 - 4 = 8 years.
#
# Step 3: Calculate your partner's current age.
#
# * You are now 20 years old, and the age difference remains constant.  Therefore, your partner is 20 + 8 = 28 years old.
#
# Therefore, your partner is now $\boxed{28}$ years old.

# %% [markdown]
# # Multi-modal prompting¶
# As you may have noticed in AI Studio, the Gemini models support more than just text as input. You can provide pictures, videos, audio and more.
#
# ## Images
# Start by downloading an image.

# %%
model = genai.GenerativeModel("gemini-1.5-flash")
from PIL import Image
from IPython.display import display

# !wget -nv https://storage.googleapis.com/generativeai-downloads/images/cake.jpg -O cake.jpg
img = Image.open("cake.jpg")
display(img)
# Out:
# 2024-11-25 11:07:09 URL:https://storage.googleapis.com/generativeai-downloads/images/cake.jpg [253809/253809] -> "cake.jpg" [1]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x871>

# %%
# Assuming 'genai' and 'retry_policy' are defined elsewhere
# model = genai.GenerativeModel('gemini-1.5-flash-latest')

prompt = [
  "What is this? Please describe it in detail.",
  Image.open("cake.jpg"), # Changed PIL.Image.open to Image.open
]

response = model.generate_content(prompt)
print(response.text)
# Out:
# That's a slice of tiramisu.
#
# Tiramisu is a classic Italian dessert.  This particular serving shows a rectangular slice, meticulously presented on a white plate.  Let's break down the components:
#
# * **Layers:** The tiramisu is layered.  Visible are layers of light-colored ladyfingers (savoiardi biscuits) soaked in coffee, alternating with layers of a creamy mixture typically made with mascarpone cheese, eggs, and sugar. A thin layer of chocolate appears to be at the bottom of each serving, although this is not always the case.
#
# * **Topping:** The top is generously dusted with cocoa powder, creating a rich brown surface. Small dark chocolate shavings or dots are scattered across the cocoa powder.  A small sprig of fresh mint adds a pop of green as a garnish.
#
# ...

# %%
response = model.generate_content(
    [
        "Write a short, engaging blog post based on this picture. It should include a description of the meal in the photo and talk about my journey meal prepping.",
        img,
    ],
    stream=True,
)
response.resolve()
print(response.text)

# %% [markdown]
# Assigning a Role

# %% [markdown]
# ## Listing recipes using a json schema

# %%
# prompt: Generate a list of cookie recipes. Make the outputs in JSON format.

import json

def generate_cookie_recipes(num_recipes=5):
    model = genai.GenerativeModel('gemini-pro')
    prompt = f"""Generate {num_recipes} cookie recipes in JSON format. Each recipe should include the following fields:
    - name (string): The name of the cookie.
    - ingredients (list of strings): A list of ingredients.
    - instructions (list of strings): Step-by-step instructions.
    - notes (string, optional): Any additional notes or tips.
    """
    response = model.generate_content(prompt)
    try:
        recipes = json.loads(response.text)
        return json.dumps(recipes, indent=4)
    except json.JSONDecodeError:
        print("Error: Invalid JSON response from the model.")
        return None

# Example usage:
cookie_recipes_json = generate_cookie_recipes()
if cookie_recipes_json:
cookie_recipes_json

# %%
Generate a list of cookie recipes. Make the outputs in JSON format.

# %% [markdown]
# ## Math Tutor
# Teach me a lesson on quadratic equations. Assume I know absolutely nothing about it.

# %%
# prompt: Teach me a lesson on quadratic equations. Assume I know absolutely nothing about it.

def teach_quadratic_equations():
    model = genai.GenerativeModel('gemini-pro')
    prompt = """Teach me a lesson on quadratic equations. Assume I know absolutely nothing about it."""
    response = model.generate_content(prompt)
    print(response.text)

teach_quadratic_equations()
# Out:
# **What is a Quadratic Equation?**
#
# A quadratic equation is an equation that can be written in the form:
#
# ```
# ax² + bx + c = 0
# ```
#
# where:
#
# * **a** is a non-zero constant called the coefficient of the squared term (x²)
# * **b** is a constant called the coefficient of the linear term (x)
# * **c** is a constant called the constant term
#
# **Solving Quadratic Equations**
#
# There are several methods to solve quadratic equations, including:
#
# * **Factoring:** This involves finding two numbers that, when multiplied together, give the constant term (c) and when added together, give the coefficient of the linear term (b). Once factored, the equation can be set to zero and solved.
# * **Completing the Square:** This involves adding and subtracting a specific value to the equation to make it a perfect square trinomial. The square root can then be taken of both sides to solve for **x**.
# ...

# %% [markdown]
# Other classification examples
# ## Topic classification

# %%
prompt = """
Classify a piece of text into one of several predefined topics, such as sports, politics, or entertainment. \n
text: President Biden will be visiting India in the month of March to discuss a few opportunities. \n
class:
"""

response = model.generate_content(
    contents=prompt, generation_config=genai.GenerationConfig() # Create an instance of GenerationConfig
).text
print(response)
# Out:
# Politics

# %% [markdown]
# ## Spam detection

# %%
prompt = """
Given an email, classify it as spam or not spam. \n
email: hi user, \n
      you have been selected as a winner of the lottery and can win upto 1 million dollar. \n
      kindly share your bank details and we can proceed from there. \n\n

      from, \n
      US Official Lottry Depatmint
"""

response = model.generate_content(
    contents=prompt, generation_config=genai.GenerationConfig() # Create an instance of GenerationConfig
).text
print(response)
# Out:
# Spam.  This email uses classic spam tactics:
#
# * **Unsolicited win:**  Nobody gets notified of lottery wins via email, especially not with vague language like "upto 1 million dollar".
# * **Request for personal information:** Asking for bank details is a major red flag. Legitimate organizations never request this information via email.
# * **Poor grammar and spelling:** "upto" and "Depatmint" are clear indicators of a scam.
# * **Generic greeting:** "Hi user" is impersonal and lacks any specific details.
#
#
# The combination of these factors strongly suggests this is a phishing attempt designed to steal banking information.

# %% [markdown]
# ## Toxicity detection

# %%
prompt = """
Given a piece of text, classify it as toxic or non-toxic. \n
text: i love sunny days
"""

response = model.generate_content(
    contents=prompt, generation_config=genai.GenerationConfig() # Create an instance of GenerationConfig
).text
print(response)
# Out:
# Non-toxic

# %% [markdown]
# [You can learn more](https://github.com/google-gemini/cookbook)
